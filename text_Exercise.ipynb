# %% [markdown]
# ### Text Exercise

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/ac/66/937d1d73389c0b501c928c4d8513653063d2b40272dff70d0e283d8b9144/wordcloud-1.9.3-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading wordcloud-1.9.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.6.1 in /Users/coding/anaconda3/lib/python3.11/site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in /Users/coding/anaconda3/lib/python3.11/site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /Users/coding/anaconda3/lib/python3.11/site-packages (from wordcloud) (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/coding/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/coding/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/coding/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/coding/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/coding/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/coding/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/coding/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/coding/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp311-cp311-macosx_11_0_arm64.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 3.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3

# %%
# !pip install easyocr
# Out:
# Requirement already satisfied: easyocr in /Users/coding/anaconda3/lib/python3.11/site-packages (1.7.1)
# Requirement already satisfied: torch in /Users/coding/anaconda3/lib/python3.11/site-packages (from easyocr) (2.2.0)
# Requirement already satisfied: torchvision>=0.5 in /Users/coding/anaconda3/lib/python3.11/site-packages (from easyocr) (0.17.0)
# Requirement already satisfied: opencv-python-headless in /Users/coding/anaconda3/lib/python3.11/site-packages (from easyocr) (4.9.0.80)
# Requirement already satisfied: scipy in /Users/coding/anaconda3/lib/python3.11/site-packages (from easyocr) (1.9.3)
# Requirement already satisfied: numpy in /Users/coding/anaconda3/lib/python3.11/site-packages (from easyocr) (1.23.5)
# Requirement already satisfied: Pillow in /Users/coding/anaconda3/lib/python3.11/site-packages (from easyocr) (9.4.0)
# Requirement already satisfied: scikit-image in /Users/coding/anaconda3/lib/python3.11/site-packages (from easyocr) (0.20.0)
# Requirement already satisfied: python-bidi in /Users/coding/anaconda3/lib/python3.11/site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: PyYAML in /Users/coding/anaconda3/lib/python3.11/site-packages (from easyocr) (6.0)
# Requirement already satisfied: Shapely in /Users/coding/anaconda3/lib/python3.11/site-packages (from easyocr) (2.0.2)
# Requirement already satisfied: pyclipper in /Users/coding/anaconda3/lib/python3.11/site-packages (from easyocr) (1.3.0.post5)
# Requirement already satisfied: ninja in /Users/coding/anaconda3/lib/python3.11/site-packages (from easyocr) (1.11.1.1)
# Requirement already satisfied: requests in /Users/coding/anaconda3/lib/python3.11/site-packages (from torchvision>=0.5->easyocr) (2.28.1)
# Requirement already satisfied: filelock in /Users/coding/anaconda3/lib/python3.11/site-packages (from torch->easyocr) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/coding/anaconda3/lib/python3.11/site-packages (from torch->easyocr) (4.9.0)
# Requirement already satisfied: sympy in /Users/coding/anaconda3/lib/python3.11/site-packages (from torch->easyocr) (1.11.1)
# Requirement already satisfied: networkx in /Users/coding/anaconda3/lib/python3.11/site-packages (from torch->easyocr) (3.1)
# Requirement already satisfied: jinja2 in /Users/coding/anaconda3/lib/python3.11/site-packages (from torch->easyocr) (3.1.2)
# Requirement already satisfied: fsspec in /Users/coding/anaconda3/lib/python3.11/site-packages (from torch->easyocr) (2023.4.0)
# Requirement already satisfied: six in /Users/coding/anaconda3/lib/python3.11/site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.4.1 in /Users/coding/anaconda3/lib/python3.11/site-packages (from scikit-image->easyocr) (2.31.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /Users/coding/anaconda3/lib/python3.11/site-packages (from scikit-image->easyocr) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/coding/anaconda3/lib/python3.11/site-packages (from scikit-image->easyocr) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /Users/coding/anaconda3/lib/python3.11/site-packages (from scikit-image->easyocr) (23.1)
# Requirement already satisfied: lazy_loader>=0.1 in /Users/coding/anaconda3/lib/python3.11/site-packages (from scikit-image->easyocr) (0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/coding/anaconda3/lib/python3.11/site-packages (from jinja2->torch->easyocr) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/coding/anaconda3/lib/python3.11/site-packages (from requests->torchvision>=0.5->easyocr) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/coding/anaconda3/lib/python3.11/site-packages (from requests->torchvision>=0.5->easyocr) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/coding/anaconda3/lib/python3.11/site-packages (from requests->torchvision>=0.5->easyocr) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/coding/anaconda3/lib/python3.11/site-packages (from requests->torchvision>=0.5->easyocr) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /Users/coding/anaconda3/lib/python3.11/site-packages (from sympy->torch->easyocr) (1.3.0)

# %%
import easyocr
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
reader = easyocr.Reader(['en'])

# %%
extracted_text = reader.readtext('image.png')

# %%
print(extracted_text)
# Out:
# [([[0, 46], [1179, 46], [1179, 134], [0, 134]], 'Bachelorstudium Data Science', 0.9214951586805677), ([[0, 208], [1147, 208], [1147, 269], [0, 269]], 'Expertin oder Experte fur Kunstliche Intelligenz werden', 0.7658900215129512), ([[48, 472], [256, 472], [256, 522], [48, 522]], 'Eckdaten', 0.9962957946737876), ([[50, 596], [206, 596], [206, 628], [50, 628]], 'Abschluss', 0.9961950373737298), ([[697, 593], [901, 593], [901, 629], [697, 629]], 'ECTS-Punkte', 0.9999561130201888), ([[47, 636], [665, 636], [665, 677], [47, 677]], 'Bachelor of Science FHNW in Data Science', 0.9004029117666572), ([[698, 640], [754, 640], [754, 672], [698, 672]], '180', 0.9999927044989317), ([[47, 725], [265, 725], [265, 761], [47, 761]], 'Studienmodus', 0.9998540476973666), ([[698, 726], [752, 726], [752, 758], [698, 758]], 'Ort', 0.9999318630507482), ([[47, 769], [619, 769], [619, 805], [47, 805]], 'Flexibel und individualisiert. Vollzeit und', 0.8356752495406155), ([[695, 765], [930, 765], [930, 813], [695, 813]], 'Brugg-Windisch', 0.9999407388285129), ([[49, 817], [157, 817], [157, 853], [49, 853]], 'Teilzeit', 0.9999940151400932), ([[61, 941], [951, 941], [951, 979], [61, 979]], 'Anmeldeschluss fir den Studienstart im Herbst ist der 31. Mai:', 0.7574013661604909), ([[169, 1050], [502, 1050], [502, 1089], [169, 1089]], 'Zu den Info-Anlassen', 0.5664290846784665), ([[869, 1045], [1260, 1045], [1260, 1094], [869, 1094]], 'Anmeldung zum Studium', 0.9998153334524146)]

# %%
for (bbox,text,prob) in extracted_text:
    print((bbox,text,prob))
# Out:
# ([[0, 46], [1179, 46], [1179, 134], [0, 134]], 'Bachelorstudium Data Science', 0.9214951586805677)
# ([[0, 208], [1147, 208], [1147, 269], [0, 269]], 'Expertin oder Experte fur Kunstliche Intelligenz werden', 0.7658900215129512)
# ([[48, 472], [256, 472], [256, 522], [48, 522]], 'Eckdaten', 0.9962957946737876)
# ([[50, 596], [206, 596], [206, 628], [50, 628]], 'Abschluss', 0.9961950373737298)
# ([[697, 593], [901, 593], [901, 629], [697, 629]], 'ECTS-Punkte', 0.9999561130201888)
# ([[47, 636], [665, 636], [665, 677], [47, 677]], 'Bachelor of Science FHNW in Data Science', 0.9004029117666572)
# ([[698, 640], [754, 640], [754, 672], [698, 672]], '180', 0.9999927044989317)
# ([[47, 725], [265, 725], [265, 761], [47, 761]], 'Studienmodus', 0.9998540476973666)
# ([[698, 726], [752, 726], [752, 758], [698, 758]], 'Ort', 0.9999318630507482)
# ([[47, 769], [619, 769], [619, 805], [47, 805]], 'Flexibel und individualisiert. Vollzeit und', 0.8356752495406155)
# ([[695, 765], [930, 765], [930, 813], [695, 813]], 'Brugg-Windisch', 0.9999407388285129)
# ([[49, 817], [157, 817], [157, 853], [49, 853]], 'Teilzeit', 0.9999940151400932)
# ([[61, 941], [951, 941], [951, 979], [61, 979]], 'Anmeldeschluss fir den Studienstart im Herbst ist der 31. Mai:', 0.7574013661604909)
# ([[169, 1050], [502, 1050], [502, 1089], [169, 1089]], 'Zu den Info-Anlassen', 0.5664290846784665)
# ([[869, 1045], [1260, 1045], [1260, 1094], [869, 1094]], 'Anmeldung zum Studium', 0.9998153334524146)

# %%
text = ' '.join([item[1] for item in extracted_text])
print(concatenated_text)

wordcloud = WordCloud().generate(text)




wordcloud = WordCloud(background_color="white",max_words=len(text),max_font_size=40, relative_scaling=.5).generate(text)

plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
# Out:
# Bachelorstudium Data Science Expertin oder Experte fur Kunstliche Intelligenz werden Eckdaten Abschluss ECTS-Punkte Bachelor of Science FHNW in Data Science 180 Studienmodus Ort Flexibel und individualisiert. Vollzeit und Brugg-Windisch Teilzeit Anmeldeschluss fir den Studienstart im Herbst ist der 31. Mai: Zu den Info-Anlassen Anmeldung zum Studium
